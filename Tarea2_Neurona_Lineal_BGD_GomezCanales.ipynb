# %% [markdown]
# # Neurona Lineal

# %% [markdown]
# Paso 1. Corre la siguiente casilla para importar la paquetería necesaria

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Paso 2. Revisa el siguiente código de la red neuronal lineal y completa las líneas que faltan

# %%
class Linear_Neuron:
    
    def __init__(self,  n_inputs, learning_rate=0.1):
        # Aleatorios entre -1 y 1
        self.w = -1 + 2 * np.random.rand(n_inputs)
        self.b = -1 + 2 * np.random.rand()
        self.eta = learning_rate
        
    def predict(self, X):
        Y_est = np.dot(self.w, X) + self.b
        return Y_est

    def train(self, X, Y, epochs=50):
        _, p = X.shape
        for _ in range(epochs):
            Y_est = self.predict(X)
            # Completa las siguientes líneas de código
            self.w += self.eta / p * ((Y - Y_est) @ X.T).reshape(-1)
            self.b += self.eta / p * np.sum(Y - Y_est)

# %% [markdown]
# Paso 3. Corre el siguiente ejemplo

# %%
p = 100
# Tamano de x es [1, 100]
x = - 1 + 2 * np.random.rand(p).reshape(1, -1)  # Aleatorios entre -1 y 1
y = -18 * x + 6  + 3 * np.random.rand(p)  # El ultimo termino anade ruido
plt.plot(x, y, '.b')

neuron = Linear_Neuron(1, 0.1)
neuron.train(x, y, epochs=100) 

# Dibujar linea
xn = np.array([[-1, 1]])
plt.plot(xn.ravel(), neuron.predict(xn), "--r")
plt.show()
